# %%
from keras.datasets import mnist
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
import os
from glob import glob
from scipy import ndimage, misc
from keras import backend as K
import numpy as np
K.set_image_dim_ordering('tf')
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /Users/lemakikuchi/anaconda/envs/tensorflow/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from glob import glob
from scipy import ndimage, misc

# %%
path = glob("c_faces/*.jpg")

# %%
path
# Out:
# ['c_faces/Ed.jpg', 'c_faces/Ed1.jpg']

# %%
for p in path:
    try:
        temp = misc.imresize(ndimage.imread(p), (218,178))
        name = p.replace('c_faces/','c_faces218178/')
        print temp.shape
        if temp.shape != (218, 178, 3):
            continue
        misc.imsave(name, temp)
    except:
        continue
# Out:
# (218, 178, 3)
# (218, 178, 3)

# %%
218/178.0
# Out:
# 1.2247191011235956

# %%
419/267.0
# Out:
# 1.5692883895131087

# %%
760/620.0
# Out:
# 1.2258064516129032

# %%
for p in path:
    temp = misc.imread(p)
    print temp.shape
# Out:
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# (218, 178, 3)
# ...

# %%
path64 = glob("paintings218178/*.jpg")

# %%
len(path64)
# Out:
# 50728

# %%
def rndlist(times):
    templist = []
    slist = np.random.choice(path64, times)
    for p in slist:
        temp = ndimage.imread(p).astype('float32')
        templist.append(temp)
        data = np.array(templist)
    return data

# %%
rndlist(1).shape

# %%
shift = 0.2

# %%
datagen_list = [ImageDataGenerator(rotation_range=90), ImageDataGenerator(width_shift_range=shift, height_shift_range=shift), ImageDataGenerator(horizontal_flip=True, vertical_flip=True)]

# %%
#datagen_list = [ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True), ImageDataGenerator(rotation_range=90), ImageDataGenerator(width_shift_range=shift, height_shift_range=shift), ImageDataGenerator(horizontal_flip=True, vertical_flip=True)]

# %%
len(datagen_list)
# Out:
# 3

# %%
#datagen = ImageDataGenerator(width_shift_range=shift, height_shift_range=shift)

# %%
#datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)

# %%
#datagen.fit(data)

# %%
#os.makedirs('pics')

# %%
for y in range(100):
    d = rndlist(500)
    fname = 'aug' + '_' + str(y)
    for x in datagen_list:
        datagen = x
        datagen.fit(d)
        for X_batch, y_batch in datagen.flow(d, d, batch_size=len(d), save_to_dir='paintings_aug', save_prefix=fname, save_format='jpg'):
            break

# %%
d = rndlist(5)

# %%
for x in datagen_list:
    datagen = x
    datagen.fit(d)
    for X_batch, y_batch in datagen.flow(d, d, batch_size=len(d), save_to_dir='pics', save_prefix='aug', save_format='png'):
        for i in range(0, len(d)):
#            pyplot.subplot(330 + 1 + i)
#            pyplot.imshow(X_batch[i].reshape(64, 64, 3))
            X_batch[i].reshape(64, 64, 3)
#        pyplot.show()
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8feaf22f8a11> in <module>()
#       1 for x in datagen_list:
#       2     datagen = x
# ----> 3     datagen.fit(d)
#       4     for X_batch, y_batch in datagen.flow(d, d, batch_size=len(d), save_to_dir='pics', save_prefix='aug', save_format='png'):
#       5         for i in range(0, len(d)):
#
# /Users/lemakikuchi/anaconda/envs/tensorflow/lib/python2.7/site-packages/keras/preprocessing/image.pyc in fit(self, X, augment, rounds, seed)
#     413             flatX = np.reshape(X, (X.shape[0], X.shape[1] * X.shape[2] * X.shape[3]))
#     414             sigma = np.dot(flatX.T, flatX) / flatX.shape[0]
# --> 415             U, S, V = linalg.svd(sigma)
#     416             self.principal_components = np.dot(np.dot(U, np.diag(1. / np.sqrt(S + 10e-7))), U.T)
#     417
#
# ...

# %%
for X_batch, y_batch in datagen.flow(data, data, batch_size=len(data), save_to_dir='test2', save_prefix='aug', save_format='png'):
	# create a grid of 3x3 images
	for i in range(0, 9):
		pyplot.subplot(330 + 1 + i)
		pyplot.imshow(X_batch[i].reshape(64, 64, 3))
	# show the plot
	pyplot.show()
	break
